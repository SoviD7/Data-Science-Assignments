# %% [markdown]
# # Data Science Assignment 12 : Naive Bayes

# %% [markdown]
# ### 1. Prepare a classification model using Naive Bayes for salary data
#
# Data Description:
#
# age -- age of a person
# workclass	-- A work class is a grouping of work
# education	-- Education of an individuals
# maritalstatus -- Marital status of an individulas
# occupation	 -- occupation of an individuals
# relationship --
# race --  Race of an Individual
# sex --  Gender of an Individual
# capitalgain --  profit received from the sale of an investment
# capitalloss	-- A decrease in the value of a capital asset
# hoursperweek -- number of hours work per week
# native -- Native of an individual
# Salary -- salary of an individual

# %%
# Import libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mlxtend
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ## SalaryData_Train

# %%
# importing train dataaset
Train=pd.read_csv(r"SalaryData_Train.csv.crdownload")
Train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male       2174.0
# 1     Exec-managerial         Husband   White     Male          0.0
# 2   Handlers-cleaners   Not-in-family   White     Male          0.0
# 3   Handlers-cleaners         Husband   Black     Male          0.0
# 4      Prof-specialty            Wife   Black   Female          0.0
#
#    capitalloss  hoursperweek          native  Salary
# 0          0.0          40.0   United-States   <=50K
# 1          0.0          13.0   United-States   <=50K
# 2          0.0          40.0   United-States   <=50K
# 3          0.0          40.0   United-States   <=50K
# 4          0.0          40.0            Cuba   <=50K

# %% [markdown]
# ### Performing EDA & Visualization on "Train" dataset

# %% [markdown]
# #### EDA

# %%
Train.shape
# Out:
# (16008, 14)

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16008 entries, 0 to 16007
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            16008 non-null  int64
#  1   workclass      16008 non-null  object
#  2   education      16008 non-null  object
#  3   educationno    16008 non-null  int64
#  4   maritalstatus  16008 non-null  object
#  5   occupation     16008 non-null  object
#  6   relationship   16007 non-null  object
#  7   race           16007 non-null  object
#  8   sex            16007 non-null  object
#  9   capitalgain    16007 non-null  float64
#  10  capitalloss    16007 non-null  float64
#  11  hoursperweek   16007 non-null  float64
#  12  native         16007 non-null  object
#  13  Salary         16007 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 1.7+ MB

# %%
Train.isnull().any()
# Out:
# age              False
# workclass        False
# education        False
# educationno      False
# maritalstatus    False
# occupation       False
# relationship      True
# race              True
# sex               True
# capitalgain       True
# capitalloss       True
# hoursperweek      True
# native            True
# Salary            True
# dtype: bool

# %%
# Checking descriptive statistics of dataset
Train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  16008.000000  16008.000000  16007.000000  16007.000000  16007.000000
# mean      38.435970     10.133246   1057.912913     88.413632     40.931967
# std       13.130512      2.535052   7244.250233    402.786387     11.892714
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
# checking Duplicate raws
Train[Train.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15967   23   Private   Some-college           10   Married-civ-spouse
# 15968   59   Private        HS-grad            9   Married-civ-spouse
# 15979   32   Private      Bachelors           13        Never-married
# 15981   34   Private   Some-college           10        Never-married
# 16002   33   Private   Some-college           10   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 326       Exec-managerial         Husband   White     Male          0.0
# 364          Craft-repair   Not-in-family   White     Male          0.0
# 518     Handlers-cleaners       Unmarried   Black   Female          0.0
# 525          Craft-repair       Own-child   White     Male          0.0
# 619       Exec-managerial         Husband   White     Male          0.0
# ...                   ...             ...     ...      ...          ...
# 15967   Handlers-cleaners         Husband   White     Male          0.0
# 15968        Craft-repair         Husband   White     Male          0.0
# 15979        Adm-clerical   Not-in-family   White     Male          0.0
# 15981        Craft-repair   Not-in-family   White     Male          0.0
# 16002      Prof-specialty         Husband   White     Male          0.0
#
#        capitalloss  hoursperweek          native  Salary
# 326            0.0          40.0   United-States    >50K
# 364            0.0          50.0   United-States   <=50K
# 518            0.0          40.0   United-States   <=50K
# 525            0.0          40.0   United-States   <=50K
# 619            0.0          40.0   United-States    >50K
# ...            ...           ...             ...     ...
# 15967          0.0          40.0   United-States   <=50K
# 15968          0.0          40.0   United-States   <=50K
# 15979          0.0          40.0   United-States   <=50K
# 15981          0.0          40.0   United-States   <=50K
# 16002          0.0          40.0   United-States   <=50K
#
# [1126 rows x 14 columns]

# %%
df1=Train.drop_duplicates()
df1
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 16003   57        Federal-gov        HS-grad            9
# 16004   55            Private           10th            6
# 16005   21            Private           10th            6
# 16006   36   Self-emp-not-inc        Masters           14
# 16007   26            Private   Some-college           10
#
#              maritalstatus          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial          Husband   White
# 2                 Divorced   Handlers-cleaners    Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners          Husband   Black
# 4       Married-civ-spouse      Prof-specialty             Wife   Black
# ...                    ...                 ...              ...     ...
# 16003            Separated        Adm-clerical   Other-relative   Black
# 16004              Widowed    Transport-moving    Not-in-family   Black
# 16005   Married-civ-spouse        Craft-repair          Husband   White
# 16006   Married-civ-spouse      Prof-specialty          Husband   White
# 16007        Never-married            Prof-spe              NaN     NaN
#
#            sex  capitalgain  capitalloss  hoursperweek          native  Salary
# 0         Male       2174.0          0.0          40.0   United-States   <=50K
# 1         Male          0.0          0.0          13.0   United-States   <=50K
# 2         Male          0.0          0.0          40.0   United-States   <=50K
# 3         Male          0.0          0.0          40.0   United-States   <=50K
# 4       Female          0.0          0.0          40.0            Cuba   <=50K
# ...        ...          ...          ...           ...             ...     ...
# 16003   Female          0.0          0.0          35.0   United-States   <=50K
# 16004   Female          0.0          0.0          35.0   United-States   <=50K
# 16005     Male          0.0          0.0          40.0   United-States   <=50K
# 16006     Male          0.0          0.0          45.0   United-States    >50K
# 16007      NaN          NaN          NaN           NaN             NaN     NaN
#
# [14882 rows x 14 columns]

# %%
# Checking Correlation between numerical function
correlation = df1.corr()
correlation
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.033254     0.067796     0.059337      0.075621
# educationno   0.033254     1.000000     0.121459     0.080201      0.150339
# capitalgain   0.067796     0.121459     1.000000    -0.034495      0.078300
# capitalloss   0.059337     0.080201    -0.034495     1.000000      0.051643
# hoursperweek  0.075621     0.150339     0.078300     0.051643      1.000000

# %%
# Checking Correlation between numerical function
correlationX = Train.corr() # correlation withour droping duplicated raws
correlationX
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.034766     0.070102     0.064108      0.093335
# educationno   0.034766     1.000000     0.120279     0.080261      0.152025
# capitalgain   0.070102     0.120279     1.000000    -0.032057      0.078933
# capitalloss   0.064108     0.080261    -0.032057     1.000000      0.053899
# hoursperweek  0.093335     0.152025     0.078933     0.053899      1.000000

# %% [markdown]
# #### Visualization

# %%
# creating heatmap by use of correlation
plt.figure(figsize=(6,6))
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
# ploting pair plot to visualise the attributes all at once
sns.pairplot(data=Train, hue = 'maritalstatus')

# %%
sns.pairplot(data=Train, hue = 'sex')

# %% [markdown]
# #### Calculating Unique Values

# %%
Train['workclass'].unique(), Train['workclass'].value_counts()
# Out:
# (array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#         ' Local-gov', ' Self-emp-inc', ' Without-pay'], dtype=object),
#   Private             11838
#   Self-emp-not-inc     1335
#   Local-gov            1066
#   State-gov             690
#   Self-emp-inc          569
#   Federal-gov           505
#   Without-pay             5
#  Name: workclass, dtype: int64)

# %%
Train['education'].unique(), Train['education'].value_counts()
# Out:
# (array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#         ' Some-college', ' Assoc-acdm', ' 7th-8th', ' Doctorate',
#         ' Assoc-voc', ' Prof-school', ' 5th-6th', ' 10th', ' Preschool',
#         ' 12th', ' 1st-4th'], dtype=object),
#   HS-grad         5282
#   Some-college    3526
#   Bachelors       2718
#   Masters          878
#   Assoc-voc        679
#   11th             555
#   Assoc-acdm       517
#   10th             435
#   7th-8th          296
#   Prof-school      274
#   9th              241
#   Doctorate        196
#   12th             173
#   5th-6th          145
#   1st-4th           74
#   Preschool         19
#  Name: education, dtype: int64)

# %%
Train['maritalstatus'].unique(), Train['maritalstatus'].value_counts()
# Out:
# (array([' Never-married', ' Married-civ-spouse', ' Divorced',
#         ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#         ' Widowed'], dtype=object),
#   Married-civ-spouse       7449
#   Never-married            5181
#   Divorced                 2232
#   Separated                 496
#   Widowed                   441
#   Married-spouse-absent     198
#   Married-AF-spouse          11
#  Name: maritalstatus, dtype: int64)

# %%
Train['occupation'].unique(), Train['occupation'].value_counts()
# Out:
# (array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#         ' Prof-specialty', ' Other-service', ' Sales', ' Transport-moving',
#         ' Farming-fishing', ' Machine-op-inspct', ' Tech-support',
#         ' Craft-repair', ' Protective-serv', ' Armed-Forces',
#         ' Priv-house-serv', ' Prof-spe'], dtype=object),
#   Prof-specialty       2136
#   Craft-repair         2108
#   Exec-managerial      2091
#   Adm-clerical         2058
#   Sales                1937
#   Other-service        1722
#   Machine-op-inspct    1055
#   Transport-moving      848
#   Handlers-cleaners     673
#   Farming-fishing       492
#   Tech-support          464
#   Protective-serv       337
#   Priv-house-serv        82
#   Armed-Forces            4
#   Prof-spe                1
#  Name: occupation, dtype: int64)

# %%
Train['race'].unique(), Train['race'].value_counts()
# Out:
# (array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#         ' Other', nan], dtype=object),
#   White                 13785
#   Black                  1508
#   Asian-Pac-Islander      463
#   Amer-Indian-Eskimo      139
#   Other                   112
#  Name: race, dtype: int64)

# %%
Train['sex'].unique(), Train['sex'].value_counts()
# Out:
# (array([' Male', ' Female'], dtype=object),
#   Male      20380
#   Female     9781
#  Name: sex, dtype: int64)

# %%
Train['native'].unique(), Train['native'].value_counts()
# Out:
# (array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#         ' Puerto-Rico', ' Honduras', ' England', ' Canada', ' Germany',
#         ' Iran', ' Philippines', ' Poland', ' Columbia', ' Cambodia',
#         ' Thailand', ' Ecuador', ' Laos', ' Taiwan', ' Haiti', ' Portugal',
#         ' Dominican-Republic', ' El-Salvador', ' France', ' Guatemala',
#         ' Italy', ' China', ' South', ' Japan', ' Yugoslavia', ' Peru',
#         ' Outlying-US(Guam-USVI-etc)', ' Scotland', ' Trinadad&Tobago',
#         ' Greece', ' Nicaragua', ' Vietnam', ' Hong', ' Ireland',
#         ' Hungary'], dtype=object),
#   United-States                 27504
#   Mexico                          610
#   Philippines                     188
#   Germany                         128
#   Puerto-Rico                     109
#   Canada                          107
#   India                           100
#   El-Salvador                     100
#   Cuba                             92
#   England                          86
#   Jamaica                          80
#   South                            71
#   China                            68
#   Italy                            68
#   Dominican-Republic               67
#   Vietnam                          64
#   Guatemala                        63
#   Japan                            59
#   Poland                           56
#   Columbia                         56
#   Iran                             42
#   Taiwan                           42
#   Haiti                            42
#   Portugal                         34
#   Nicaragua                        33
#   Peru                             30
#   Greece                           29
#   France                           27
#   Ecuador                          27
#   Ireland                          24
#   Hong                             19
#   Cambodia                         18
#   Trinadad&Tobago                  18
#   Laos                             17
#   Thailand                         17
#   Yugoslavia                       16
#   Outlying-US(Guam-USVI-etc)       14
#   Hungary                          13
#   Honduras                         12
#   Scotland                         11
#  Name: native, dtype: int64)

# %%
Train['native'].unique(), Train['native'].value_counts()
# Out:
# (array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#         ' Puerto-Rico', ' Honduras', ' England', ' Canada', ' Germany',
#         ' Iran', ' Philippines', ' Poland', ' Columbia', ' Cambodia',
#         ' Thailand', ' Ecuador', ' Laos', ' Taiwan', ' Haiti', ' Portugal',
#         ' Dominican-Republic', ' El-Salvador', ' France', ' Guatemala',
#         ' Italy', ' China', ' South', ' Japan', ' Yugoslavia', ' Peru',
#         ' Outlying-US(Guam-USVI-etc)', ' Scotland', ' Trinadad&Tobago',
#         ' Greece', ' Nicaragua', ' Vietnam', ' Hong', ' Ireland',
#         ' Hungary'], dtype=object),
#   United-States                 27504
#   Mexico                          610
#   Philippines                     188
#   Germany                         128
#   Puerto-Rico                     109
#   Canada                          107
#   India                           100
#   El-Salvador                     100
#   Cuba                             92
#   England                          86
#   Jamaica                          80
#   South                            71
#   China                            68
#   Italy                            68
#   Dominican-Republic               67
#   Vietnam                          64
#   Guatemala                        63
#   Japan                            59
#   Poland                           56
#   Columbia                         56
#   Iran                             42
#   Taiwan                           42
#   Haiti                            42
#   Portugal                         34
#   Nicaragua                        33
#   Peru                             30
#   Greece                           29
#   France                           27
#   Ecuador                          27
#   Ireland                          24
#   Hong                             19
#   Cambodia                         18
#   Trinadad&Tobago                  18
#   Laos                             17
#   Thailand                         17
#   Yugoslavia                       16
#   Outlying-US(Guam-USVI-etc)       14
#   Hungary                          13
#   Honduras                         12
#   Scotland                         11
#  Name: native, dtype: int64)

# %%
# Ploting Countolot for Categorical data

plt.subplots(figsize=(20,16))
[plt.subplot(4,2,1), sns.countplot(data=Train, y='workclass')];

[plt.subplot(4,2,2), sns.countplot(data=Train, y='education')];

[plt.subplot(4,2,3), sns.countplot(data=Train, y='maritalstatus')];

[plt.subplot(4,2,4), sns.countplot(data=Train, y='occupation')];

[plt.subplot(4,2,5), sns.countplot(data=Train, y='relationship')];

[plt.subplot(4,2,6), sns.countplot(data=Train, y='race')];

[plt.subplot(4,2,7), sns.countplot(data=Train, y='sex')];

[plt.subplot(4,2,8), sns.countplot(data=Train, y='Salary')];

# %%
no_columns = Train.select_dtypes(exclude='object').columns.tolist()
plt.figure(figsize=(15,10))
for i,column in enumerate(no_columns,1):
    plt.subplot(2,3,i)
    sns.kdeplot(Train[column],color='g',shade=True)

# %% [markdown]
# #### Ploting Boplot for numerical data

# %%
plt.figure(figsize=(12,12))
[plt.subplot(3,2,1), sns.boxplot(x=Train["age"])];

[plt.subplot(3,2,2), sns.boxplot(x=Train["educationno"])];

[plt.subplot(3,2,3), sns.boxplot(x=Train["capitalgain"])];

[plt.subplot(3,2,4), sns.boxplot(x=Train["capitalloss"])];

[plt.subplot(3,2,5), sns.boxplot(x=Train["hoursperweek"])];

# %% [markdown]
# #### Converting categorical data into Label Encoding data

# %%
# Convering values of "salary" column with use of "convert" function

convert = {' >50K': 1, ' <=50K': 2}
df1 = df1.replace({'Salary': convert})

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

columns=["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
for i in columns:
    df1[i]= label_encoder.fit_transform(df1[i])
    
df1
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30154   53          2         12           14              2           3
# 30155   22          2         15           10              4          10
# 30156   27          2          7           12              2          12
# 30158   58          2         11            9              6           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 1     4    1         2174            0            40
# 1                 0     4    1            0            0            13
# 2                 1     4    1            0            0            40
# 3                 0     2    1            0            0            40
# 4                 5     2    0            0            0            40
# ...             ...   ...  ...          ...          ...           ...
# 30154             0     4    1            0            0            40
# 30155             1     4    1            0            0            40
# 30156             5     4    0            0            0            38
# 30158             4     4    0            0            0            40
# 30160             5     4    0        15024            0            40
#
#        native  Salary
# 0          37       2
# 1          37       2
# 2          37       2
# 3          37       2
# 4           4       2
# ...       ...     ...
# 30154      37       1
# 30155      37       2
# 30156      37       2
# 30158      37       2
# 30160      37       1
#
# [26903 rows x 14 columns]

# %% [markdown]
# ## SalaryData_Test

# %%
# importing test dataaset
Test=pd.read_csv(r"SalaryData_Test.csv.crdownload")
Test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %% [markdown]
# ### Performing EDA & Visualization on "Test" dataset

# %% [markdown]
# #### EDA

# %%
Test.shape
# Out:
# (15060, 14)

# %%
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
Test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
Test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
Test[Test.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# 551         Other-service   Not-in-family   White   Female            0
# 601                 Sales         Husband   White     Male            0
# 681          Craft-repair         Husband   White     Male            0
# 799        Prof-specialty   Not-in-family   White     Male            0
# 1044       Prof-specialty         Husband   White     Male        99999
# ...                   ...             ...     ...      ...          ...
# 15043        Craft-repair         Husband   White     Male            0
# 15044        Craft-repair       Own-child   White     Male            0
# 15049   Handlers-cleaners         Husband   White     Male            0
# 15052        Craft-repair         Husband   White     Male            0
# 15053       Other-service       Own-child   White   Female            0
#
#        capitalloss  hoursperweek          native  Salary
# 551              0            40   United-States   <=50K
# 601              0            40   United-States   <=50K
# 681              0            40   United-States   <=50K
# 799              0            35   United-States   <=50K
# 1044             0            60   United-States    >50K
# ...            ...           ...             ...     ...
# 15043            0            40   United-States   <=50K
# 15044            0            40   United-States   <=50K
# 15049            0            40   United-States   <=50K
# 15052            0            40   United-States   <=50K
# 15053            0            40   United-States   <=50K
#
# [930 rows x 14 columns]

# %%
# Correlation
# Checking Correlation between numerical function
correlationXx = Test.corr() # correlation without droping duplicated raws
correlationXx
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.026123     0.078760     0.057745      0.102758
# educationno   0.026123     1.000000     0.131750     0.085817      0.133691
# capitalgain   0.078760     0.131750     1.000000    -0.031876      0.090501
# capitalloss   0.057745     0.085817    -0.031876     1.000000      0.057712
# hoursperweek  0.102758     0.133691     0.090501     0.057712      1.000000

# %% [markdown]
# #### Visualization

# %%
# creating heatmap by use of correlation
plt.figure(figsize=(6,6))
sns.heatmap(correlationXx,annot=True)
# Out:
# <AxesSubplot:>

# %%
df2=Test.drop_duplicates()
df2
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [14130 rows x 14 columns]

# %%
Test['workclass'].unique(), Test['workclass'].value_counts()
# Out:
# (array([' Private', ' Local-gov', ' Self-emp-not-inc', ' Federal-gov',
#         ' State-gov', ' Self-emp-inc', ' Without-pay'], dtype=object),
#   Private             11021
#   Self-emp-not-inc     1297
#   Local-gov            1033
#   State-gov             667
#   Self-emp-inc          572
#   Federal-gov           463
#   Without-pay             7
#  Name: workclass, dtype: int64)

# %%
Test['education'].unique(), Test['education'].value_counts()
# Out:
# (array([' 11th', ' HS-grad', ' Assoc-acdm', ' Some-college', ' 10th',
#         ' Prof-school', ' 7th-8th', ' Bachelors', ' Masters', ' 5th-6th',
#         ' Assoc-voc', ' 9th', ' Doctorate', ' 12th', ' 1st-4th',
#         ' Preschool'], dtype=object),
#   HS-grad         4943
#   Some-college    3221
#   Bachelors       2526
#   Masters          887
#   Assoc-voc        652
#   11th             571
#   Assoc-acdm       499
#   10th             403
#   7th-8th          266
#   Prof-school      243
#   9th              221
#   12th             200
#   Doctorate        169
#   5th-6th          161
#   1st-4th           71
#   Preschool         27
#  Name: education, dtype: int64)

# %%
Test['maritalstatus'].unique(), Test['maritalstatus'].value_counts()
# Out:
# (array([' Never-married', ' Married-civ-spouse', ' Widowed', ' Separated',
#         ' Divorced', ' Married-spouse-absent', ' Married-AF-spouse'],
#        dtype=object),
#   Married-civ-spouse       6990
#   Never-married            4872
#   Divorced                 2083
#   Separated                 472
#   Widowed                   450
#   Married-spouse-absent     182
#   Married-AF-spouse          11
#  Name: maritalstatus, dtype: int64)

# %%
Test['occupation'].unique(), Test['occupation'].value_counts()
# Out:
# (array([' Machine-op-inspct', ' Farming-fishing', ' Protective-serv',
#         ' Other-service', ' Prof-specialty', ' Craft-repair',
#         ' Adm-clerical', ' Exec-managerial', ' Tech-support', ' Sales',
#         ' Priv-house-serv', ' Transport-moving', ' Handlers-cleaners',
#         ' Armed-Forces'], dtype=object),
#   Exec-managerial      1992
#   Craft-repair         1990
#   Prof-specialty       1970
#   Sales                1824
#   Adm-clerical         1819
#   Other-service        1596
#   Machine-op-inspct    1004
#   Transport-moving      744
#   Handlers-cleaners     696
#   Tech-support          508
#   Farming-fishing       491
#   Protective-serv       332
#   Priv-house-serv        89
#   Armed-Forces            5
#  Name: occupation, dtype: int64)

# %%
Test['relationship'].unique(), Test['relationship'].value_counts()
# Out:
# (array([' Own-child', ' Husband', ' Not-in-family', ' Unmarried', ' Wife',
#         ' Other-relative'], dtype=object),
#   Husband           6203
#   Not-in-family     3976
#   Own-child         2160
#   Unmarried         1576
#   Wife               685
#   Other-relative     460
#  Name: relationship, dtype: int64)

# %%
Test['race'].unique(), Test['race'].value_counts()
# Out:
# (array([' Black', ' White', ' Other', ' Amer-Indian-Eskimo',
#         ' Asian-Pac-Islander'], dtype=object),
#   White                 12970
#   Black                  1411
#   Asian-Pac-Islander      408
#   Amer-Indian-Eskimo      149
#   Other                   122
#  Name: race, dtype: int64)

# %%
Test['sex'].unique(), Test['sex'].value_counts()
# Out:
# (array([' Male', ' Female'], dtype=object),
#   Male      10147
#   Female     4913
#  Name: sex, dtype: int64)

# %%
Test['occupation'].unique(), Test['occupation'].value_counts()
# Out:
# (array([' Machine-op-inspct', ' Farming-fishing', ' Protective-serv',
#         ' Other-service', ' Prof-specialty', ' Craft-repair',
#         ' Adm-clerical', ' Exec-managerial', ' Tech-support', ' Sales',
#         ' Priv-house-serv', ' Transport-moving', ' Handlers-cleaners',
#         ' Armed-Forces'], dtype=object),
#   Exec-managerial      1992
#   Craft-repair         1990
#   Prof-specialty       1970
#   Sales                1824
#   Adm-clerical         1819
#   Other-service        1596
#   Machine-op-inspct    1004
#   Transport-moving      744
#   Handlers-cleaners     696
#   Tech-support          508
#   Farming-fishing       491
#   Protective-serv       332
#   Priv-house-serv        89
#   Armed-Forces            5
#  Name: occupation, dtype: int64)

# %%
Test['native'].unique(), Test['native'].value_counts()
# Out:
# (array([' United-States', ' Peru', ' Guatemala', ' Mexico',
#         ' Dominican-Republic', ' Ireland', ' Germany', ' Philippines',
#         ' Thailand', ' Haiti', ' El-Salvador', ' Puerto-Rico', ' Vietnam',
#         ' South', ' Columbia', ' Japan', ' India', ' Cambodia', ' Poland',
#         ' Laos', ' England', ' Cuba', ' Taiwan', ' Italy', ' Canada',
#         ' Portugal', ' China', ' Nicaragua', ' Honduras', ' Iran',
#         ' Scotland', ' Jamaica', ' Ecuador', ' Yugoslavia', ' Hungary',
#         ' Hong', ' Greece', ' Trinadad&Tobago',
#         ' Outlying-US(Guam-USVI-etc)', ' France'], dtype=object),
#   United-States                 13788
#   Mexico                          293
#   Philippines                      95
#   Puerto-Rico                      66
#   Germany                          65
#   Canada                           56
#   El-Salvador                      47
#   India                            47
#   China                            45
#   Cuba                             41
#   England                          33
#   Italy                            32
#   South                            30
#   Dominican-Republic               30
#   Japan                            30
#   Portugal                         28
#   Haiti                            27
#   Columbia                         26
#   Poland                           25
#   Guatemala                        23
#   Jamaica                          23
#   Greece                           20
#   Vietnam                          19
#   Ecuador                          16
#   Nicaragua                        15
#   Peru                             15
#   Iran                             14
#   Taiwan                           13
#   Thailand                         12
#   Ireland                          12
#   Hong                              9
#   Scotland                          9
#   France                            9
#   Outlying-US(Guam-USVI-etc)        8
#   Trinadad&Tobago                   8
#   Cambodia                          8
#   Yugoslavia                        7
#   Honduras                          7
#   Hungary                           5
#   Laos                              4
#  Name: native, dtype: int64)

# %%
Test['Salary'].unique(), Test['Salary'].value_counts()
# Out:
# (array([' <=50K', ' >50K'], dtype=object),
#   <=50K    11360
#   >50K      3700
#  Name: Salary, dtype: int64)

# %% [markdown]
# #### Converting categorical data into Label Encoding data

# %%
for i in columns:
    df2[i]= label_encoder.fit_transform(df2[i])
    
df2
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 3     2    1            0            0            40
# 1                 0     4    1            0            0            50
# 2                 0     4    1            0            0            40
# 3                 0     2    1         7688            0            40
# 4                 1     4    1            0            0            30
# ...             ...   ...  ...          ...          ...           ...
# 15055             3     4    1            0            0            40
# 15056             1     4    0            0            0            36
# 15057             0     4    1            0            0            50
# 15058             3     1    1         5455            0            40
# 15059             0     4    1            0            0            60
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37    >50K
# 3          37    >50K
# 4          37   <=50K
# ...       ...     ...
# 15055      37   <=50K
# 15056      37   <=50K
# 15057      37   <=50K
# 15058      37   <=50K
# 15059      37    >50K
#
# [14130 rows x 14 columns]

# %%
# Convering values of "salary" column with use of "convert" function

convert = {' >50K': 1, ' <=50K': 2}
df2 = df2.replace({'Salary': convert})

# %%
df2
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 3     2    1            0            0            40
# 1                 0     4    1            0            0            50
# 2                 0     4    1            0            0            40
# 3                 0     2    1         7688            0            40
# 4                 1     4    1            0            0            30
# ...             ...   ...  ...          ...          ...           ...
# 15055             3     4    1            0            0            40
# 15056             1     4    0            0            0            36
# 15057             0     4    1            0            0            50
# 15058             3     1    1         5455            0            40
# 15059             0     4    1            0            0            60
#
#        native  Salary
# 0          37       2
# 1          37       2
# 2          37       1
# 3          37       1
# 4          37       2
# ...       ...     ...
# 15055      37       2
# 15056      37       2
# 15057      37       2
# 15058      37       2
# 15059      37       1
#
# [14130 rows x 14 columns]

# %% [markdown]
# ### Applying Naive Bayes

# %%
x_train = df1.iloc[:,0:13]
y_train = df1.iloc[:,13]
x_test = df2.iloc[:,0:13]
y_test = df2.iloc[:,13]

# %% [markdown]
# #### 1. Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
clsfrgnb = GaussianNB()   
# clsfrgnb = claasification with Gussian Naive Bayes

# %%
# Model Making
model1=clsfrgnb.fit(x_train, y_train)

# %%
# Prediction with x_test
y_pred_gnb = model1.predict(x_test)  # gnb=gausian naive bayes

# %%
y_pred_gnb
# Out:
# array([2, 2, 2, ..., 2, 1, 2], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred_gnb)   #Confusion matrix
# Out:
# array([[ 1180,  2330],
#        [  564, 10056]], dtype=int64)

# %%
pd.crosstab(y_test.values.flatten(),clsfrgnb)
# Out:
# col_0  GaussianNB()
# row_0
# 1              3510
# 2             10620

# %%
print ("Accuracy",np.mean(y_pred_gnb==y_test.values.flatten())*100)
# Out:
# Accuracy 79.51875442321303

# %% [markdown]
# #### 2. Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
clsfrmnb = MultinomialNB()   
# clsfrgnb = claasification with Multinominal Naive Bayes

# %%
model2=clsfrmnb.fit(x_train, y_train)
model2
# Out:
# MultinomialNB()

# %%
y_pred_mnb = model2.predict(x_test)   
# mnb=Multinominal naive bayes

# %%
# Confusion Metrix
confusion_matrix(y_test, y_pred_mnb)
# Out:
# array([[  777,  2733],
#        [  469, 10151]], dtype=int64)

# %%
pd.crosstab(y_test.values.flatten(),clsfrmnb)
# Out:
# col_0  MultinomialNB()
# row_0
# 1                 3510
# 2                10620

# %%
print ("Accuracy",np.mean(y_pred_mnb==y_test.values.flatten()))
# Out:
# Accuracy 0.7733899504600141

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_mnb)
# Out:
# 0.7733899504600141

# %% [markdown]
# #### 3. Cross Validation Check

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
seed = 7
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('MNB', MultinomialNB()))

# %%
results = []
names = []
scoring = 'accuracy'

# %%
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed,shuffle = True)
    cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.796230 (0.006124)
# KNN: 0.824777 (0.010738)
# CART: 0.785712 (0.006551)
# NB: 0.793703 (0.010001)
# MNB: 0.768316 (0.008122)

# %%
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# ### Here I compare with different algorithms for checking which algorith gives us higher accuracy
#
# ### After comparing "KNN" gives higher accuracy, Accuracy of KNN = 0.824777
